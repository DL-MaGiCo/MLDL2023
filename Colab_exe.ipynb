# %% [markdown]
# ## Setup environment - every time

# %% [markdown]
# Every time you restart Colab's kernel, you have to mount to your GDrive and to re-install packages and download anything that was not saved into your GDrive.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Dataset unzip

# %%
# move into your mounted GDrive filesystem
# %cd /content/drive/MyDrive/Progetto/Datasets

# unzip the datasets to /content, so you don't risk going over the GDrive storage limit
# this can take a few minutes
# !unzip -q gsv_xs.zip -d /content
# !unzip -q tokyo_xs.zip -d /content
# !unzip -q sf_xs.zip -d /content

# %%
#install requirements
# !pip install -r requirements.txt

# %%
# TRAIN

# !python train.py --train_path /content/gsv_xs/train --val_path  /content/sf_xs/val --test_path /content/tokyo_xs/test --max_epochs 10 --exp_name 'mix' --optim 'adamw' --loss 'fast' --lr '0.001' --wd '0.0001' #--checkpoint

# %%
# TEST

# !python eval.py --test_path /content/sf_xs/test --checkpoint #'/content/drive/MyDrive/Progetto/Simple_VPR_codebase/NEW_LOGS/lightning_logs/version_1/checkpoints/mix_sgd_lr_0.001_wd_0.001_epoch(09)_step(9770)_R@1[0.0000]_R@5[0.0000].ckpt'
